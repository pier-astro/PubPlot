# %%
import matplotlib.pyplot as plt
import numpy as np

pt = 1/72.27  # points in inches
jour_sizes = {"aanda": {"onecol": 256.*pt, "twocol": 523.5*pt},
              "apj": {"onecol": 242.*pt},
             }

# export sizes as yaml
import yaml
with open("journals.yaml", "w") as f:
    yaml.dump(jour_sizes, f)




# Generate sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x) / 10  # Scale down to avoid large values
y4 = np.log1p(x)  # log(1+x) to avoid log(0)
y5 = np.sqrt(x)
# Out:
# Bad key legend.labelsize in file aanda.mplstyle, line 10 ('legend.labelsize: 9')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.10.6/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution

# %%
# plotting
plt.figure(figsize=(size, size/golden))
plt.plot(x, y1, label='sin(x)')
plt.plot(x, y2, label='cos(x)')
plt.plot(x, y3, label='tan(x)/10')
plt.plot(x, y4, label='log(1+x)')
plt.plot(x, y5, label='sqrt(x)')
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.xlabel('X-axis')
plt.ylabel('Y-axis (log scale)')
plt.title('We present, for the first time')
plt.legend()
plt.show()

# %%
# I want to make a python library that makes publication quality plots for
# different journals with the correct sizes and styles.
# The library should allow users to select the journal and column format,
# and it should automatically apply the appropriate styles and dimensions to the plots.
# Be wary! The library should NOT handle the plotting itself, just the styles and sizes.
# Users should be able to use their preferred plotting libraries (e.g., Matplotlib, Seaborn)
# while benefiting from the standardized styles and sizes provided by the library.
# The library should be easy to use and integrate into existing workflows.
# The library should also be extensible, allowing users to add support for additional journals
# and customize styles as needed.
